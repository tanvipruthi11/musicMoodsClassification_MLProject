# %% [markdown]
# ## **DATASET DESCRIPTION**

# %% [markdown]
# The dataset for our project "Songs mood Classification" is taken from Kaggle
# (https://www.kaggle.com/archiewebster/happysad). It consists of 32k+ songs features and classifies them into happy and sad moods. This labelled dataset will be our ground truth. The explanation of each audio features have been referred from Spotify Webpage and have also been listed at the end of this notebook for reference.
#
# We have performed the exploratory analysis on the dataset and plotted different visualisation for understanding the correlation between the datasets and understand the patterns on how they classify into happy or sad moods.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Read the dataset
df = pd.read_csv("dataset.csv")
# removing key and duration column from the dataframe
fdf = df.drop(['key', 'duration'], axis=1)

# %% [markdown]
# # **DATA ANALYSIS AND VISUALISATION**

# %% [markdown]
# ## **1. Identifying Correlation between all the features**

# %%
plt.figure(figsize=(16, 6))
heatmap = sns.heatmap(fdf.corr(), vmin=-1, vmax=1, annot=True, cmap='Blues')
heatmap.set_title('Showing Features Correlation', fontdict={'fontsize':12}, pad=12)
plt.show()

# %% [markdown]
# We were able to have below observations from the above heatmap visualisation -
#
# 1.   From the above heatmap, we could see that the energy and loudness are highly proportional and correlated.
# 2.   Valence is equally related to danceability and energy.
# 3.   Minor Features Seggregation: Instrumentalness, liveness, Speechiness, and tempo, acousticness
# 4.   Major Features Seggregation: Energy, loudness, valence, danceability

# %% [markdown]
# ## 2. **Happy Vs Sad Songs Correlation with Major Features**

# %%
# shows no difference - can be removed!!!
happysongs_df = fdf[fdf['h/s'] == 'h']
sadsongs_df = fdf[fdf['h/s'] == 's']
happysongs_df_major_features = happysongs_df[['valence', 'danceability', 'energy', 'loudness']]
sadsongs_df_major_features = sadsongs_df[['valence', 'danceability', 'energy', 'loudness']]

fig, ax = plt.subplots(1,2,figsize=(15,5))

heatmap1 = sns.heatmap(happysongs_df_major_features.corr(), vmin=-1, vmax=1, annot=True, cmap='Blues', ax=ax[0])
heatmap1.set_title('Happy songs Features Correlation', fontdict={'fontsize':12}, pad=12)

heatmap2 = sns.heatmap(sadsongs_df_major_features.corr(), vmin=-1, vmax=1, annot=True, cmap='Blues', ax=ax[1])
heatmap2.set_title('Sad songs Features Correlation', fontdict={'fontsize':12}, pad=12)
plt.show()

# %% [markdown]
# ## **3. Features Analysis and Visualisation**

# %%
# TAKING 100 SONGS FOR VISUALISATION PURPOSE
happysongs_df_major_features = happysongs_df.head(100)
happysongs_df_major_features['classification'] = 'happy'
sadsongs_df_major_features = sadsongs_df.head(100)
sadsongs_df_major_features['classification'] = 'sad'
concat_df = pd.concat([happysongs_df_major_features, sadsongs_df_major_features])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
# plot
fig, ax = plt.subplots(4,8,figsize=(35,15))
g = sns.scatterplot(y="danceability", x="energy", hue="classification", data=concat_df, ax=ax[0][0])
g = sns.scatterplot(y="loudness", x="energy", hue="classification", data=concat_df, ax=ax[0][1])
g = sns.scatterplot(y="valence", x="energy", hue="classification", data=concat_df, ax=ax[0][2])
g = sns.scatterplot(y="acousticness", x="energy", hue="classification", data=concat_df, ax=ax[0][3])
g = sns.scatterplot(y="instrumentalness", x="energy", hue="classification", data=concat_df, ax=ax[0][4])
g = sns.scatterplot(y="liveness", x="energy", hue="classification", data=concat_df, ax=ax[0][5])
g = sns.scatterplot(y="speechiness", x="energy", hue="classification", data=concat_df, ax=ax[0][6])
g = sns.scatterplot(y="tempo", x="energy", hue="classification", data=concat_df, ax=ax[0][7])


g = sns.scatterplot(y="energy", x="danceability", hue="classification", data=concat_df, ax=ax[1][0])
g = sns.scatterplot(y="loudness", x="danceability", hue="classification", data=concat_df, ax=ax[1][1])
g = sns.scatterplot(y="valence", x="danceability", hue="classification", data=concat_df, ax=ax[1][2])
g = sns.scatterplot(y="acousticness", x="danceability", hue="classification", data=concat_df, ax=ax[1][3])
g = sns.scatterplot(y="instrumentalness", x="danceability", hue="classification", data=concat_df, ax=ax[1][4])
g = sns.scatterplot(y="liveness", x="danceability", hue="classification", data=concat_df, ax=ax[1][5])
g = sns.scatterplot(y="speechiness", x="danceability", hue="classification", data=concat_df, ax=ax[1][6])
g = sns.scatterplot(y="tempo", x="danceability", hue="classification", data=concat_df, ax=ax[1][7])

g = sns.scatterplot(y="danceability", x="loudness", hue="classification", data=concat_df, ax=ax[2][0])
g = sns.scatterplot(y="energy", x="loudness", hue="classification", data=concat_df, ax=ax[2][1])
g = sns.scatterplot(y="valence", x="loudness", hue="classification", data=concat_df, ax=ax[2][2])
g = sns.scatterplot(y="acousticness", x="loudness", hue="classification", data=concat_df, ax=ax[2][3])
g = sns.scatterplot(y="instrumentalness", x="loudness", hue="classification", data=concat_df, ax=ax[2][4])
g = sns.scatterplot(y="liveness", x="loudness", hue="classification", data=concat_df, ax=ax[2][5])
g = sns.scatterplot(y="speechiness", x="loudness", hue="classification", data=concat_df, ax=ax[2][6])
g = sns.scatterplot(y="tempo", x="loudness", hue="classification", data=concat_df, ax=ax[2][7])

g = sns.scatterplot(y="danceability", x="valence", hue="classification", data=concat_df, ax=ax[3][0])
g = sns.scatterplot(y="loudness", x="valence", hue="classification", data=concat_df, ax=ax[3][1])
g = sns.scatterplot(y="energy", x="valence", hue="classification", data=concat_df, ax=ax[3][2])
g = sns.scatterplot(y="acousticness", x="valence", hue="classification", data=concat_df, ax=ax[3][3])
g = sns.scatterplot(y="instrumentalness", x="valence", hue="classification", data=concat_df, ax=ax[3][4])
g = sns.scatterplot(y="liveness", x="valence", hue="classification", data=concat_df, ax=ax[3][5])
g = sns.scatterplot(y="speechiness", x="valence", hue="classification", data=concat_df, ax=ax[3][6])
g = sns.scatterplot(y="tempo", x="valence", hue="classification", data=concat_df, ax=ax[3][7])

fig.tight_layout()

# %% [markdown]
# From the above scatter plots, below are the list of observations that we were able to identify -
#
# 1. Energy is low for the Sad songs, and high for the happy songs.
# 2. Instrumentalness is 0 almost for all songs and hence this feature can be dropped out.
# 3. Valence is spread out.
# 4. Danceability for most of the sad and happy songs lie between 0.45 to 0.75
# 5. Most songs are low on liveness and speechiness

# %%
############### WITH A SINGLE FEATURE ##################
plt.figure(figsize=(6, 6))
heatmap = sns.heatmap(fdf.corr()[['energy']].sort_values(by='energy', ascending=False), vmin=-1, vmax=1, annot=True, cmap='Blues')
heatmap.set_title('Features Correlating with Energy', fontdict={'fontsize':18}, pad=16);

plt.show()

# %% [markdown]
# ### **3b Instrumentalness**
#
# It was seen from below histogram, that most of the songs had 0 or close to 0 value. Hence, we decided to drop this parameter.

# %%
from matplotlib.pyplot import hist
counts, bins = np.histogram(fdf.instrumentalness)
plt.hist(bins[:-1], bins, weights=counts)
# Out:
# (array([31939.,   739.,   463.,   332.,   269.,   273.,   342.,   423.,
#           810.,   816.]),
#  array([0.    , 0.0994, 0.1988, 0.2982, 0.3976, 0.497 , 0.5964, 0.6958,
#         0.7952, 0.8946, 0.994 ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ## **Features Definitions from Spotify Webpage.**

# %% [markdown]
# The below definitions of different audio features have been copy/paste from Spotify Webpage.
#
#
# **Spotify Audio Features:**
# Spotify uses a series of different features to classify tracks. I copy/paste the information from the Spotify Webpage.
#
# **Acousticness:** A confidence measure from 0.0 to 1.0 of whether the track is acoustic. 1.0 represents high confidence the track is acoustic.
# Danceability: Danceability describes how suitable a track is for dancing based on a combination of musical elements including tempo, rhythm stability, beat strength, and overall regularity. A value of 0.0 is least danceable and 1.0 is most danceable.
#
# **Energy:** Energy is a measure from 0.0 to 1.0 and represents a perceptual measure of intensity and activity. Typically, energetic tracks feel fast, loud, and noisy. For example, death metal has high energy, while a Bach prelude scores low on the scale. Perceptual features contributing to this attribute include dynamic range, perceived loudness, timbre, onset rate, and general entropy.
#
# **Instrumentalness:** Predicts whether a track contains no vocals. “Ooh” and “aah” sounds are treated as instrumental in this context. Rap or spoken word tracks are clearly “vocal”. The closer the instrumentalness value is to 1.0, the greater likelihood the track contains no vocal content. Values above 0.5 are intended to represent instrumental tracks, but confidence is higher as the value approaches 1.0.
#
# **Liveness:** Detects the presence of an audience in the recording. Higher liveness values represent an increased probability that the track was performed live. A value above 0.8 provides a strong likelihood that the track is live.
# Loudness: the overall loudness of a track in decibels (dB). Loudness values are averaged across the entire track and are useful for comparing the relative loudness of tracks. Loudness is the quality of a sound that is the primary psychological correlate of physical strength (amplitude). Values typically range between -60 and 0 db.
#
# **Speechiness:** Speechiness detects the presence of spoken words in a track. The more exclusively speech-like the recording (e.g. talk show, audiobook, poetry), the closer to 1.0 the attribute value. Values above 0.66 describe tracks that are probably made entirely of spoken words. Values between 0.33 and 0.66 describe tracks that may contain both music and speech, either in sections or layered, including such cases as rap music. Values below 0.33 most likely represent music and other non-speech-like tracks.
#
# **Valence:** A measure from 0.0 to 1.0 describing the musical positiveness conveyed by a track. Tracks with high valence sound more positive (e.g. happy, cheerful, euphoric), while tracks with low valence sound more negative (e.g. sad, depressed, angry).
#
# **Tempo:** The overall estimated tempo of a track in beats per minute (BPM). In musical terminology, the tempo is the speed or pace of a given piece and derives directly from the average beat duration.
